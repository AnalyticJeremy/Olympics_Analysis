# %% [markdown]
# <img src="https://raw.githubusercontent.com/AnalyticJeremy/Olympics_Analysis/main/img/logos/olympics.svg" width="550" /><br /><br />
# <img src="https://raw.githubusercontent.com/AnalyticJeremy/Olympics_Analysis/main/img/logos/us_flag.svg" width="550" />
#
# # Analysis &mdash; USA Performance
#
# At the risk of being an "ugly American," I want to use the acquired data to explore how the US has performed at the Olympics.

# %% [markdown]
# > This is a placeholder notebook.  I will be re-implementing this functionality in Python.  For now, you can use the original [R version](R/04 Analysis - USA Performance.ipynb)
