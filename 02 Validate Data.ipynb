# %% [markdown]
# <img src="https://raw.githubusercontent.com/AnalyticJeremy/Olympics_Analysis/main/img/logos/olympics.svg" width="550" />
#
# # Validate Data
#
# Now that we have a bunch of data, we want to do a few quick sanity checks to make sure we got everything we were expecting.
# We can do this by comparing the summary statistics that we scraped with the details that we retrieved.  The details should
# add up to match the summary data.

# %% [markdown]
# > This is a placeholder notebook.  I will be re-implementing this functionality in Python.  For now, you can use the original [R version](R/02 Validate Data.ipynb)
